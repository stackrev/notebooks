# %%
import pandas as pd

# %%
data = pd.read_csv("./Mall_Customers.csv")
data.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
mean = data["Annual Income (k$)"].mean()
print(f'Mean: {mean}')
data["AboveAvg"] = data["Annual Income (k$)"] > mean
data.sample(5)
# Out:
# Mean: 60.56
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 177         178    Male   27                  88                      69
# 128         129    Male   59                  71                      11
# 57           58    Male   69                  44                      46
# 38           39  Female   36                  37                      26
# 14           15    Male   37                  20                      13
#
#      AboveAvg
# 177      True
# 128      True
# 57      False
# 38      False
# 14      False
